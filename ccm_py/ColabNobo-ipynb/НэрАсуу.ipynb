# %%
# "Сайн байна уу" гээд миний нэрийг нь асууна.
print('Сайн байна уу?')
print('Таны нэрийг хэн гэдэг вэ?') # нэрийг нь асууна
myName = input()
print('Уулзсандаа таатай байна. Эрхэм ' + myName)
print('Таны нэр хэдэн үсэгтэй вэ? гэвэл:')
print(len(myName),"үсэгтэй юм байна.") 
print('Та хэдэн настай вэ?') # насыг нь асууна
myAge = input()
print('Удахгүй ' + str(int(myAge) + 1) + ' нас хүрэх гэж байгаа юм байна.')
from datetime import datetime
currentYear = datetime.now().year
print(str(currentYear - int(myAge)) + ' онд төрсөн юм байна.')
# Out:
# Сайн байна уу?
# Таны нэрийг хэн гэдэг вэ?
# Undrakh
# Уулзсандаа таатай байна. Эрхэм Undrakh
# Таны нэр хэдэн үсэгтэй вэ? гэвэл:
# 7 үсэгтэй юм байна.
# Та хэдэн настай вэ?
# 29
# Удахгүй 30 нас хүрэх гэж байгаа юм байна.
# 1991 онд төрсөн юм байна.
