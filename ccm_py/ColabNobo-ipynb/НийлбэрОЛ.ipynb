# %%
import random

number_of_questions = 3

for i in range(1, number_of_questions + 1):
    print("Бодлого #%s" % i)

    x = random.randint(1, 9)
    y = random.randint(1, 9)

    print("+-------------+")
    print("| %s + %s = ? |" % (x, y))
    print("+-------------+")

    a = input ("Таны хариулт:")
    a = int(a)

    if x + y == a:
      print("***ЗӨВ***")
    else:
      print("***БУРУУ***")
# Out:
# Бодлого #1
# +-------------+
# | 8 + 9 = ? |
# +-------------+
# Таны хариулт:17
# ***ЗӨВ***
# Бодлого #2
# +-------------+
# | 7 + 1 = ? |
# +-------------+
# Таны хариулт:8
# ***ЗӨВ***
# Бодлого #3
# +-------------+
# | 8 + 7 = ? |
# +-------------+
# Таны хариулт:15
# ***ЗӨВ***
