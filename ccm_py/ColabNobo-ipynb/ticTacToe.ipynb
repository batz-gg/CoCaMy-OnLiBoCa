# %%
theBoard = {'ЗүүДээ': ' ', 'ГолДээ': ' ', 'БарДээ': ' ',
            'ЗүүДун': ' ', 'ГолДун': ' ', 'БарДун': ' ',
            'ЗүүДоо': ' ', 'ГолДоо': ' ', 'БарДоо': ' '}
def printBoard(board):
    print(board['ЗүүДээ'] + '|' + board['ГолДээ'] + '|' + board['БарДээ'])
    print('-+-+-')
    print(board['ЗүүДун'] + '|' + board['ГолДун'] + '|' + board['БарДун'])
    print('-+-+-')
    print(board['ЗүүДоо'] + '|' + board['ГолДоо'] + '|' + board['БарДоо'])
turn = 'X'
for i in range(9):
    printBoard(theBoard)
    print(turn +'-ийн ээлж. Аль зай руу зөөх үү?')
    print('ЗүүДээ | ГолДээ | БарДээ')
    print('-------+--------+-------')
    print('ЗүүДун | ГолДун | БарДун')
    print('-------+--------+-------')
    print('ЗүүДоо | ГолДоо | БарДоо')
    move = input()
    theBoard[move] = turn
    if turn == 'X':
        turn = 'O'
    else:
        turn = 'X'
printBoard(theBoard)
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# X-ийн ээлж. Аль зай руу зөөх үү?
# ЗүүДээ | ГолДээ | БарДээ
# -------+--------+-------
# ЗүүДун | ГолДун | БарДун
# -------+--------+-------
# ЗүүДоо | ГолДоо | БарДоо
# ГолДун
#  | |
# -+-+-
#  |X|
# -+-+-
#  | |
# O-ийн ээлж. Аль зай руу зөөх үү?
# ЗүүДээ | ГолДээ | БарДээ
# -------+--------+-------
# ЗүүДун | ГолДун | БарДун
# -------+--------+-------
# ЗүүДоо | ГолДоо | БарДоо
# БарДун
#  | |
# -+-+-
#  |X|O
# -+-+-
#  | |
# X-ийн ээлж. Аль зай руу зөөх үү?
# ЗүүДээ | ГолДээ | БарДээ
# -------+--------+-------
# ЗүүДун | ГолДун | БарДун
# -------+--------+-------
# ЗүүДоо | ГолДоо | БарДоо
# БарДээ
#  | |X
# -+-+-
#  |X|O
# -+-+-
#  | |
# O-ийн ээлж. Аль зай руу зөөх үү?
# ЗүүДээ | ГолДээ | БарДээ
# -------+--------+-------
# ЗүүДун | ГолДун | БарДун
# -------+--------+-------
# ЗүүДоо | ГолДоо | БарДоо
# ЗүүДээ
# O| |X
# -+-+-
#  |X|O
# -+-+-
#  | |
# X-ийн ээлж. Аль зай руу зөөх үү?
# ЗүүДээ | ГолДээ | БарДээ
# -------+--------+-------
# ...
